# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install pandasql

# %% [markdown]
# ### Data Loading --> Mampu memuat data dengan pandas

# %%
data = pd.read_csv (r'C:\Users\Asus\Desktop\Pokemon.csv')

# %%
df_data = data

# %%
df_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df_data.head ()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df_data.tail ()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df_data.describe ()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# ### Missing Values  --> Mampu Menangani Missing Values

# %%
df_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df_data.shape
# Out:
# (800, 13)

# %%
print (df_data ['Type 1'].value_counts (dropna = False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df_data ['Type 2'].value_counts (dropna = False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Water        14
# Ghost        14
# Rock         14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
df_data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df_data ['Type 1'] = df_data ['Type 1']. astype ('category')
df_data ['Speed'] = df_data ['Speed']. astype ('float')

# %%
df_data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# Total            int64
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
df_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    float64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(8), object(2)
# memory usage: 71.2+ KB

# %%
data_1 = df_data

# %%
data_1.head ()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65   45.0           1      False
# 1       80       80   60.0           1      False
# 2      100      100   80.0           1      False
# 3      122      120   80.0           1      False
# 4       60       50   65.0           1      False

# %%
data_1.dropna (inplace = True)

# %%
data_1.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           414 non-null    int64
#  1   Name        414 non-null    object
#  2   Type 1      414 non-null    category
#  3   Type 2      414 non-null    object
#  4   Total       414 non-null    int64
#  5   HP          414 non-null    int64
#  6   Attack      414 non-null    int64
#  7   Defense     414 non-null    int64
#  8   Sp. Atk     414 non-null    int64
#  9   Sp. Def     414 non-null    int64
#  10  Speed       414 non-null    float64
#  11  Generation  414 non-null    int64
#  12  Legendary   414 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(8), object(2)
# memory usage: 40.4+ KB

# %% [markdown]
# ### Manipulating Coloumns --> Mampu mengganti nama kolom, Mampu menghapus kolom yang tidak digunakan

# %%
data_1.head ()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65   45.0           1      False
# 1       80       80   60.0           1      False
# 2      100      100   80.0           1      False
# 3      122      120   80.0           1      False
# 6      109       85  100.0           1      False

# %%
data_1.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           414 non-null    int64
#  1   Name        414 non-null    object
#  2   Type 1      414 non-null    category
#  3   Type 2      414 non-null    object
#  4   Total       414 non-null    int64
#  5   HP          414 non-null    int64
#  6   Attack      414 non-null    int64
#  7   Defense     414 non-null    int64
#  8   Sp. Atk     414 non-null    int64
#  9   Sp. Def     414 non-null    int64
#  10  Speed       414 non-null    float64
#  11  Generation  414 non-null    int64
#  12  Legendary   414 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(8), object(2)
# memory usage: 40.4+ KB

# %%
data_1 ['Legendary'].unique ()
# Out:
# array([False,  True])

# %%
data_1.head ()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65   45.0           1      False
# 1       80       80   60.0           1      False
# 2      100      100   80.0           1      False
# 3      122      120   80.0           1      False
# 6      109       85  100.0           1      False

# %%
data_1 = data_1 [['Name','Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Speed', 'Generation', 'Legendary']]

# %%
data_1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                Charizard     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Speed  Generation  Legendary
# 0     45.0           1      False
# ...

# %%
# 1. Buat functionnya untuk memetakan data yang diinginkan
# 0 -> False
# 1 -> True

def convert_Legendary(row):
    if row['Legendary'] == False:
        return '0'
    elif row['Legendary'] == True:
        return '1'
    else:
        return 'Unknown'
    

# 2. Apply functionnya

data_1['Legendary_Status'] = data_1.apply(convert_Legendary, axis=1)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
data_1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                Charizard     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Speed  Generation  Legendary Legendary_Status
# 0     45.0           1      False                0
# ...

# %%
data_1 ['Legendary_Status'].unique ()
# Out:
# array(['0', '1'], dtype=object)

# %%
data_1 = data_1.drop ('Legendary', axis = 1)

# %%
data_1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                Charizard     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Speed  Generation Legendary_Status
# 0     45.0           1                0
# ...

# %% [markdown]
# ### Data Query --> Mampu membuat minimal 3 query data

# %%
# !pip install pandasql
import pandasql

# %%
data_1.head ()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49   45.0
# 1                Ivysaur  Grass  Poison    405  60      62       63   60.0
# 2               Venusaur  Grass  Poison    525  80      82       83   80.0
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123   80.0
# 6              Charizard   Fire  Flying    534  78      84       78  100.0
#
#    Generation Legendary_Status
# 0           1                0
# 1           1                0
# 2           1                0
# 3           1                0
# 6           1                0

# %%
data_1 ['Speed'].mean ()
# Out:
# 70.51449275362319

# %% [markdown]
# ### Query 1

# %%
data_group = data_1.groupby (['Type 1'], as_index = False) ['Legendary_Status'].count ()\
                   .rename (columns = {'Legendary_Status' : 'Total'})\
                   .sort_values ('Total', ascending = False)

# %%
data_group
# Out:
#       Type 1  Total
# 17     Water     53
# 0        Bug     52
# 12    Normal     37
# 9      Grass     37
# 15      Rock     35
# 6       Fire     24
# 8      Ghost     22
# 16     Steel     22
# 2     Dragon     21
# 1       Dark     21
# 10    Ground     19
# 14   Psychic     19
# 3   Electric     17
# 13    Poison     13
# 11       Ice     11
# 5   Fighting      7
# 4      Fairy      2
# 7     Flying      2

# %%
sns.barplot (data = data_group, x = 'Type 1', y = 'Total')
plt.xlabel ('Type 1')
plt.ylabel ('Total')
plt.xticks (rotation = 45)
plt.show ()

# %% [markdown]
# ### Query 2

# %%
query = """
        SELECT 
            *
        FROM
            data_1
        WHERE
            Attack > Defense
        GROUP BY
            Name
        """
result = pandasql.sqldf(query)

result
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# 0                    Abomasnow     Grass       Ice    494   90      92
# 1      AbomasnowMega Abomasnow     Grass       Ice    594   90     132
# 2         AegislashBlade Forme     Steel     Ghost    520   60     150
# 3                   Aerodactyl      Rock    Flying    515   80     105
# 4    AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# ..                         ...       ...       ...    ...  ...     ...
# 218                    Yveltal      Dark    Flying    680  126     131
# 219                     Zapdos  Electric    Flying    580   90      90
# 220                     Zekrom    Dragon  Electric    680  100     150
# 221                      Zubat    Poison    Flying    245   40      45
# 222                   Zweilous      Dark    Dragon    420   72      85
#
#      Defense  Speed  Generation Legendary_Status
# 0         75   60.0           4                0
# ...

# %%
Attack = result.groupby ('Type 1', as_index = False) ['Legendary_Status'].count ()\
               .rename (columns = {'Legendary_Status' : 'Total'})\
               .sort_values ('Total', ascending = False)

# %%
Attack
# Out:
#       Type 1  Total
# 10    Normal     29
# 0        Bug     27
# 15     Water     21
# 7      Grass     19
# 13      Rock     18
# 5       Fire     17
# 2     Dragon     16
# 1       Dark     15
# 8     Ground     13
# 12   Psychic     10
# 11    Poison      9
# 6      Ghost      8
# 3   Electric      7
# 9        Ice      7
# 4   Fighting      5
# 14     Steel      2

# %%
sns.barplot (data = Attack, x = 'Type 1', y = 'Total')
plt.xlabel ('Type 1')
plt.ylabel ('total')
plt.xticks (rotation = 45)
plt.show ()

# %% [markdown]
# ### Query 3

# %%
df_data.head ()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65   45.0           1      False
# 1       80       80   60.0           1      False
# 2      100      100   80.0           1      False
# 3      122      120   80.0           1      False
# 6      109       85  100.0           1      False

# %%
Generation_1 = df_data.groupby ('Generation', as_index = False) ['Legendary'].count ()\
                      .rename (columns = {'Legendary' : 'Total'})\
                      .sort_values ('Total', ascending = False)
Generation_1
# Out:
#    Generation  Total
# 2           3     82
# 4           5     82
# 0           1     78
# 3           4     67
# 1           2     55
# 5           6     50

# %%
sns.barplot (data = Generation_1, x = 'Generation', y = 'Total')
plt.xlabel ('Generation')
plt.ylabel ('Total')
plt.show ()

# %% [markdown]
# ### Query 4

# %%
df_data ['Total'].mean ()
# Out:
# 456.6280193236715

# %%
df_data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
query = """
        SELECT 
            *
        FROM
            data_1
        WHERE
            Total > 456
        GROUP BY
            Name
        """
result = pandasql.sqldf(query)

result
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0                  Abomasnow     Grass       Ice    494   90      92       75
# 1    AbomasnowMega Abomasnow     Grass       Ice    594   90     132      105
# 2       AegislashBlade Forme     Steel     Ghost    520   60     150       50
# 3      AegislashShield Forme     Steel     Ghost    520   60      50      150
# 4                 Aerodactyl      Rock    Flying    515   80     105       65
# ..                       ...       ...       ...    ...  ...     ...      ...
# 225                  Yanmega       Bug    Flying    515   86      76       86
# 226                  Yveltal      Dark    Flying    680  126     131       95
# 227                   Zapdos  Electric    Flying    580   90      90       85
# 228                   Zekrom    Dragon  Electric    680  100     150      120
# 229         Zygarde50% Forme    Dragon    Ground    600  108     100      121
#
# ...

# %%
Generation = result.groupby ('Generation', as_index = False) ['Legendary_Status'].count ()\
                   .rename (columns = {'Legendary_Status' : 'Total'})\
                   .sort_values ('Total', ascending = False)

# %%
Generation
# Out:
#    Generation  Total
# 4           5     49
# 3           4     44
# 2           3     42
# 0           1     41
# 5           6     30
# 1           2     24

# %%
sns.barplot (data = Generation, x = 'Generation', y = 'Total')
plt.xlabel ('Generation')
plt.ylabel ('Total')
plt.xticks (rotation = 45)
plt.show ()

# %% [markdown]
# ### Query 5

# %%
# 1. Buat functionnya untuk memetakan data yang diinginkan
# 0 -> False
# 1 -> True

def convert_Type(row):
    if row['Type 1'] == row ['Type 2']:
        return '1'
    elif row['Type 1'] != row ['Type 2']:
        return '0'
    else:
        return 'UNKNOWN'
    

# 2. Apply functionnya

data_1['Dual_Type'] = data_1.apply(convert_Type, axis=1)

# %%
data_1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                Charizard     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Speed  Generation Legendary_Status Dual_Type
# 0     45.0           1                0         0
# ...

# %% [markdown]
# ### Kesimpulan

# %%
#1. Semua pokemon adalah dual type
#2. Type 1 pokemon terbanyak adalah bug dan water
#3. Type 1 normal adalah pokemon terbanyak dengan nilai attack > defense
#4. Ketika attack > defense, generation terbanyak adalah generation 5
