# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("/content/book/Pokemon.csv")
df.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 13 columns]

# %% [markdown]
# Import data yang berisikan informasi detil Pokemon dengan memperlihatkan urutan 10 teratas.

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 790  714               Noibat   Flying  ...    55           6      False
# 791  715              Noivern   Flying  ...   123           6      False
# 792  716              Xerneas    Fairy  ...    99           6       True
# 793  717              Yveltal     Dark  ...    99           6       True
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [10 rows x 13 columns]

# %% [markdown]
# Informasi detil Pokemon dengan memperlihatkan urutan 10 terbawah.

# %%
df.shape
# Out:
# (800, 13)

# %%
Menunjukan informasi terkait jumlah baris 800 dan kolom 13.

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# Data menunjukan tipe dari masing masing informasi yang ada didalam kolom yang tersedia.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# Memperlihatkan ada tidaknya sel yang terisi pada suatu kolom dan ini diperlihatkan pada kolom Type 2 dimana terdapat 414 cel yang terisi dan sisanya tidak terisi dimana terdapat total 800 baris.

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
Korfirmasi atas info sebelumnya berkaitan jumlah sel yang terisi adalah 414 sehingga dapat kita lihat pada kolom Type 2 terdapat 386 sel yang tidak terisi dan bila ditotal maka jumlah sel akan sama yaitu 800.

# %%
df.describe()
# Out:
#                 #      Total          HP  ...     Sp. Def       Speed  Generation
# count  800.000000  800.00000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750  435.10250   69.258750  ...   71.902500   68.277500     3.32375
# std    208.343798  119.96304   25.534669  ...   27.828916   29.060474     1.66129
# min      1.000000  180.00000    1.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000  330.00000   50.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000  450.00000   65.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000  515.00000   80.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  780.00000  255.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 9 columns]

# %% [markdown]
# Dari data diatas kita dapat melihat statistik sederhana dari data Pokemon yang meliputi jumlah, rata-rata, standar deviasi, nilai minimum hingga maksimum.

# %%
del_column = ["Generation", "Legendary"]
df.drop(del_column, inplace=True, axis=1)

# %% [markdown]
# Langkah dalam menghapus kolom yang dianggap kurang atau tidak perlu dalam pengamatan seperti kolom Generation dan Legendary.

# %%
df["Type 2"].fillna(value="None",inplace=True)
df.head(15)
# Out:
#      #                       Name Type 1  ... Sp. Atk  Sp. Def  Speed
# 0    1                  Bulbasaur  Grass  ...      65       65     45
# 1    2                    Ivysaur  Grass  ...      80       80     60
# 2    3                   Venusaur  Grass  ...     100      100     80
# 3    3      VenusaurMega Venusaur  Grass  ...     122      120     80
# 4    4                 Charmander   Fire  ...      60       50     65
# 5    5                 Charmeleon   Fire  ...      80       65     80
# 6    6                  Charizard   Fire  ...     109       85    100
# 7    6  CharizardMega Charizard X   Fire  ...     130       85    100
# 8    6  CharizardMega Charizard Y   Fire  ...     159      115    100
# 9    7                   Squirtle  Water  ...      50       64     43
# 10   8                  Wartortle  Water  ...      65       80     58
# 11   9                  Blastoise  Water  ...      85      105     78
# ...

# %% [markdown]
# Pengisian data atau informasi berkaitan kolom Type 2 yang tidak terisi data pada sel tertentu dengan data "none" serta memperlihatkan hasil dari menghapus kolom sebelumnya.

# %%
df.info()

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   #        800 non-null    int64
#  1   Name     800 non-null    object
#  2   Type 1   800 non-null    object
#  3   Type 2   800 non-null    object
#  4   Total    800 non-null    int64
#  5   HP       800 non-null    int64
#  6   Attack   800 non-null    int64
#  7   Defense  800 non-null    int64
#  8   Sp. Atk  800 non-null    int64
#  9   Sp. Def  800 non-null    int64
#  10  Speed    800 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 68.9+ KB
# (800, 11)

# %% [markdown]
# Pemerikasaan dari pegisian data pada sel kolom Type 2 yang tidak terisi dan informasi jumlah kolom dan baris didapatkan bahwa untuk kolom Type 2 sudah terisi dan untuk kolom berjumlah 11 dimana sebelumnya berjumlah 13 dan jumlah baris tetap sama yaitu 800.

# %%
df[["Name","Type 1", "Type 2", "Total"]].sort_values(by="Total", ascending= False).head(10)
# Out:
#                         Name   Type 1    Type 2  Total
# 426    RayquazaMega Rayquaza   Dragon    Flying    780
# 164      MewtwoMega Mewtwo Y  Psychic      None    780
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780
# 422      KyogrePrimal Kyogre    Water      None    770
# 424    GroudonPrimal Groudon   Ground      Fire    770
# 552                   Arceus   Normal      None    720
# 712       KyuremWhite Kyurem   Dragon       Ice    700
# 711       KyuremBlack Kyurem   Dragon       Ice    700
# 409  SalamenceMega Salamence   Dragon    Flying    700
# 413  MetagrossMega Metagross    Steel   Psychic    700

# %% [markdown]
# Menampilkan nilai total dari kolom Nama, Type 1, dan Type 2 didasarkan nilai total dari yang tertinggi serta menampilkan 10 Pokemon dengan total nilai tertinggi.

# %%
df[
   (df["HP"] > 90) &
   (df["Type 1"] == "Grass")
   ].sort_values(by="HP", ascending= False).head(10)
# Out:
#        #               Name Type 1    Type 2  ...  Defense  Sp. Atk  Sp. Def  Speed
# 741  673             Gogoat  Grass      None  ...       62       97       81     68
# 652  591          Amoonguss  Grass    Poison  ...       70       85       80     30
# 516  465          Tangrowth  Grass      None  ...      125      110       50     50
# 550  492  ShayminLand Forme  Grass      None  ...      100      100      100    100
# 551  492   ShayminSky Forme  Grass    Flying  ...       75      120       75    127
# 390  357            Tropius  Grass    Flying  ...       83       72       87     51
# 111  103          Exeggutor  Grass   Psychic  ...       85      125       65     55
# 434  389           Torterra  Grass    Ground  ...      105       75       85     56
# 701  640           Virizion  Grass  Fighting  ...       72       90      129    108
#
# [9 rows x 11 columns]

# %% [markdown]
# Menampilkan Pokemon jenis Grass pada Type 1 dengan nilai HP lebih dari 90 yang diurutkan dari nilai tertinggi.

# %%
df[(df["Sp. Atk"]>= 90)]
# Out:
#        #                       Name   Type 1  ... Speed  Generation  Legendary
# 2      3                   Venusaur    Grass  ...    80           1      False
# 3      3      VenusaurMega Venusaur    Grass  ...    80           1      False
# 6      6                  Charizard     Fire  ...   100           1      False
# 7      6  CharizardMega Charizard X     Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y     Fire  ...   100           1      False
# ..   ...                        ...      ...  ...   ...         ...        ...
# 795  719                    Diancie     Rock  ...    50           6       True
# 796  719        DiancieMega Diancie     Rock  ...   110           6       True
# 797  720        HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720         HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721                  Volcanion     Fire  ...    70           6       True
#
# [237 rows x 13 columns]

# %% [markdown]
# Hanya menampilkan Pokemon yang memiliki Sp.Atk lebih dari sama dengan 90 dimana terdapat 237 pokemon secara keseluruhan.

# %%
poke1 = df.groupby("Type 1",sort= True)["Type 1"].count()
poke2 = df.groupby("Type 2",sort= True)["Type 2"].count()
print("Pokemon",
      poke1)
print("Pokemon",
      poke2)
# Out:
# Pokemon Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Type 1, dtype: int64
# Pokemon Type 2
# Bug           3
# Dark         20
# Dragon       18
# Electric      6
# Fairy        23
# Fighting     26
# Fire         12
# Flying       97
# Ghost        14
# Grass        25
# Ground       35
# Ice          14
# None        386
# Normal        4
# Poison       34
# Psychic      33
# Rock         14
# Steel        22
# Water        14
# Name: Type 2, dtype: int64

# %% [markdown]
# Melakukan perhitungan jumlah dari pengelompokan Pokemon didasaarkan Type 1 dan Type 2.

# %%
poke1_bar = df["Type 1"].value_counts().head(18) .plot(kind="bar")
print("Pokemon Type 1")
# Out:
# Pokemon Type 1

# %% [markdown]
# Grafik batang diatas menunjukan jumlah Pokemon dari masing masing jenis pokemon pada Type 1.

# %%
piePoke = df["Type 2"].value_counts().head(18) .plot(kind="pie",autopct='%1.1f%%', figsize=(10,10))
print("Pokemon Type 2")
# Out:
# Pokemon Type 2

# %% [markdown]
# Grafik lingkaran diatas menunjukan jumlah Pokemon dari masing masing jenis pokemon pada Type 2 dalam satuan persen.

# %% [markdown]
# kesimpulannya adalah Pokemon dengan tipe Water yang mengacu pada Pokemon Type 1 memiliki jumlah tertinggi dimana totalnya adalah 112 sedangkan terendah pada tipe Flying sedangkan untuk Type 2 tipe Flying merupakan tipe dengan jumlah Pokemon terbanyak sebanyak 97 dan terendah merupakan tipe Bug yang hanya terdapat 3. Berdasarkan perhitungan makan terdapat 3 pokemon teratas dengan nilai total yang sama berjumlah 780 diantaranya adalah RayquazaMega Rayquaza, MewtwoMega Mewtwo y, dan MewtwoMega Mewtwo X. Bila mengacu pada Grass Type 1 maka akan didapat bahwa Gogoat	dengan nilai HP 123, Amoonguss dengan 114, dan Tangrowth dengan 100 yang diikuti ShayminLand Forme dan ShayminSky Forme dengan nilai yang sama. Terdpat 237 Pokemon dengan nilai Sp. Atk lebih dari sama dengan 90.
